# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Amazon.com cluster model.csv")
x=dataset.iloc[:,3:5].values

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=21)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title("wcss via elbow method")
plt.xlabel("no of clusters")
plt.ylabel("Wcss value")
plt.show()

# %%
kmeans=KMeans(n_clusters=4,init="k-means++",random_state=42)
y_means=kmeans.fit_predict(x)

# %%
print(y_means)
# Out:
# [0 0 3 0 1 0 2 3 1 3 2 0 1 0 3 3 3 3 1 3 1 1 2 1 2 3 0 0 3 2 3 1 1 3 3 1 1
#  0 1 3 3 0 2 0 2 2 0 0 1 1 1 0 1 0 3 1 1 1 3 3 0 0 2 1 3 2 3 1 3 2 0 2 3 0
#  1 1 2 0 1 0 2 3 2 1 2 0 1 3 2 2 2 3 3 1 3 1 3 0 2 2 2 0 3 2 2 3 0 3 0 2 1
#  0 2 3 3 3 2 2 0 3 0 3 0 2 0 0 0 0 2 3 2 2 3 1 3 2 0 0 1 3 0 0 1 2 1 0 0 0
#  0 1 3 2 1 3 2 2 0 1 0 0 2 1 1 0 3 1 3 2 0 0 2 1 3 2 0 3 0 1 0 3 0 2 2 1 2
#  2 1 0 3 2 1 3 1 3 3 1 3 1 0 2 3 1]

# %%
plt.scatter(x[y_means==0,0],x[y_means==0,1],s=100,c='magenta',label="cluster1")
plt.scatter(x[y_means==1,0],x[y_means==1,1],s=100,c='blue',label="cluster2")
plt.scatter(x[y_means==2,0],x[y_means==2,1],s=100,c='red',label="cluster3")
plt.scatter(x[y_means==3,0],x[y_means==3,1],s=100,c='cyan',label="cluster4")
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c="black",label="centroids")
plt.title("Cluster of Amazon users")
plt.xlabel("Annual income in INR")
plt.ylabel("Purchase rating")
plt.legend()
plt.show()
